# %%
import pandas as pd

# %%
df = pd.read_csv("../basic_data/gowalla_checkins.csv")

# %%
users_selected = df.userid.unique()[:10]
df_amostra = df.query("userid in @users_selected")
df_amostra.to_csv("../amostra_gowalla_checkins.csv")
